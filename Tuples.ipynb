# %% [markdown]
# # Tuples are similar to lists but tuples are immutable()cannot be changed
# # Tuples use parenthesis for example(1,4,5)

# %%
tuple=(1,4,8,56)

# %%
my_list=[156,23,89]

# %%
type(tuple)
# Out:
# tuple

# %%
type(my_list)
# Out:
# list

# %%
len(tuple)
# Out:
# 4

# %%
manoj=(1,4,'sharma')

# %%
manoj[-1]
# Out:
# 'sharma'

# %%
manoj[1]
# Out:
# 4

# %%
manoj
# Out:
# (1, 4, 'sharma')

# %%
t=(4,4,5,6,8,9,7,7,7)

# %%
t.count(4)
# Out:
# 2

# %%
t.count(7)
# Out:
# 3

# %%
t.index(7)
# Out:
# 6

# %% [markdown]
# # difference between a tuple and a list

# %%
my_list=[1,4,7]

# %%
my_list[0]='ram'

# %%
my_list
# Out:
# ['ram', 4, 7]

# %%
t[0]=24
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 t[0]=24
#
# TypeError: 'tuple' object does not support item assignment
