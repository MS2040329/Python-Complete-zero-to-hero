# %% [markdown]
# *lists are the ordered sequence that can hold a variety of object types.
# *[] and commas are used to separate ordered objects in a list.
# *list support indexing and slicing.

# %%
my_list=['manoj',23.6,100]

# %%
len(my_list)
# Out:
# 3

# %%
my_list[1]
# Out:
# 23.6

# %%
my_list
# Out:
# ['manoj', 23.6, 100]

# %%
another_list=['one',23+6]
another_list
# Out:
# ['one', 29]

# %%
new_list=my_list+another_list
new_list
# Out:
# ['manoj', 23.6, 100, 'one', 29]

# %%
new_list[0]='mohit'

# %%
new_list
# Out:
# ['mohit', 23.6, 100, 'one', 29]

# %%
new_list.append('chander')

# %%
new_list
# Out:
# ['mohit', 23.6, 100, 'one', 29, 'chander']

# %%
new_list.pop(2)
# Out:
# 100

# %%
new_list=['mohit',23.6,'one',29,'chander']

# %%
new_list
# Out:
# ['mohit', 23.6, 'one', 29, 'chander']

# %%
new_list.pop()
# Out:
# 'chander'

# %%
new_list
# Out:
# ['mohit', 23.6, 'one', 29]

# %%
popped_item=my_list.pop()

# %%
popped_item
# Out:
# 100

# %%
new_list
# Out:
# ['mohit', 23.6, 'one', 29]

# %%
new_list.pop(1)
# Out:
# 23.6

# %%
new_list
# Out:
# ['mohit', 'one', 29]

# %%
new_list=['a','z','x','d','f']
num_list=[1,96,4,75,10]

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'd', 'f', 'x', 'z']

# %%
num_list.sort()
num_list
# Out:
# [1, 4, 10, 75, 96]

# %%
my_sorted_list=num_list

# %%
my_sorted_list
# Out:
# [1, 4, 10, 75, 96]

# %%
num_list.reverse()

# %%
num_list
# Out:
# [96, 75, 10, 4, 1]
