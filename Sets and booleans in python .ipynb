# %% [markdown]
# # Sets are unordered collection of unique objects

# %%
myset = set()

# %%
myset
# Out:
# set()

# %%
myset.add(23)

# %%
myset
# Out:
# {23}

# %%
myset.add(00)
myset
# Out:
# {0, 23}

# %%
myset.add(23)
myset
# Out:
# {0, 23}

# %%
mylist=[1,1,1,1,1,1,2,2,2,3,3,3]
mylist
# Out:
# [1, 1, 1, 1, 1, 1, 2, 2, 2, 3, 3, 3]

# %%
set(mylist)
# Out:
# {1, 2, 3}

# %% [markdown]
# # Booleans are operators that allows you to convey true or false statement

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(False)
# Out:
# bool

# %%
1==1
# Out:
# True

# %%
2>=3
# Out:
# False

# %%
b=None
b
