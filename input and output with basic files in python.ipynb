# %%
# %%writefile myfile.txt
# this is first line
# this is second line
# this is third line
# Out:
# Writing myfile.txt

# %%
myfile=open('myfile.txt')

# %%
myfile=open('whoops_this_file_is_wrong.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 myfile=open('whoops_this_file_is_wrong.txt')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'whoops_this_file_is_wrong.txt'

# %% [markdown]
# # to print the current directory of the cell (type pwd)

# %%
pwd
# Out:
# 'C:\\Users\\ms204'

# %%
myfile=open('myfile.txt')
myfile.read()
# Out:
# 'this is first line\nthis is second line\nthis is third line\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'this is first line\nthis is second line\nthis is third line\n'

# %%
myfile=open('myfile.txt')
contents=myfile.read()

# %%
contents
# Out:
# 'this is first line\nthis is second line\nthis is third line\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# []

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['this is first line\n', 'this is second line\n', 'this is third line\n']
